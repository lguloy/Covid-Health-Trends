# %%
# %matplotlib inline

# %%
#Import Dependencies 
import requests
from scipy import stats
import pandas as pd
from CovidAct_API_key import api_key
import matplotlib.pyplot as plt

# %%
url = "https://api.covidactnow.org/v2/state/WA.timeseries.json?apiKey="

# %%
response = requests.get(url + api_key).json()
response
# Out:
# {'fips': '53',
#  'country': 'USA',
#  'state': 'WA',
#  'county': None,
#  'level': 'state',
#  'lat': None,
#  'locationId': 'iso1:us#iso2:us-wa',
#  'long': None,
#  'population': 7614893,
#  'metrics': {'testPositivityRatio': 0.04363821902357807,
#   'testPositivityRatioDetails': {'source': 'other'},
#   'caseDensity': 8.794795747153449,
#   'contactTracerCapacityRatio': 0.633703071672355,
#   'infectionRate': 0.921973937274,
#   'infectionRateCI90': 0.09999999999600007,
#   'icuHeadroomRatio': 0.17693836978131214,
#   'icuHeadroomDetails': {'currentIcuCovid': 89,
#    'currentIcuCovidMethod': 'actual',
#    'currentIcuNonCovid': 864,
#    'currentIcuNonCovidMethod': 'actual'},
#   'icuCapacityRatio': 0.6971470373079737,
#   'vaccinationsInitiatedRatio': 0.1990127766732901,
#   'vaccinationsCompletedRatio': 0.11223335639778524},
#  'riskLevels': {'overall': 1,
#   'testPositivityRatio': 1,
#   'caseDensity': 1,
#   'contactTracerCapacityRatio': 1,
#   'infectionRate': 1,
#   'icuHeadroomRatio': 0,
#   'icuCapacityRatio': 0},
#  'actuals': {'cases': 349881,
#   'deaths': 5159,
#   'positiveTests': 236922,
#   'negativeTests': 3688188,
#   'contactTracers': 2122,
#   'hospitalBeds': {'capacity': 17724,
#    'currentUsageTotal': 9912,
#    'currentUsageCovid': 423,
#    'typicalUsageRate': 0.7},
#   'icuBeds': {'capacity': 1367,
#    'currentUsageTotal': 953,
#    'currentUsageCovid': 89,
#    'typicalUsageRate': 0.67},
#   'newCases': 685,
#   'newDeaths': 18,
#   'vaccinesDistributed': 3034110,
#   'vaccinationsInitiated': 1515461,
#   'vaccinationsCompleted': 854645},
#  'annotations': {'cases': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'deaths': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'positiveTests': {'sources': [{'type': 'HHSTesting',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'negativeTests': {'sources': [{'type': 'HHSTesting',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'contactTracers': {'sources': [{'type': 'TestAndTrace',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'hospitalBeds': {'sources': [{'type': 'HHSHospital',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'icuBeds': {'sources': [{'type': 'HHSHospital', 'url': None, 'name': None}],
#    'anomalies': []},
#   'newCases': None,
#   'newDeaths': {'sources': [],
#    'anomalies': [{'date': '2020-12-29',
#      'type': 'zscore_outlier',
#      'original_observation': 133.0}]},
#   'vaccinesDistributed': {'sources': [{'type': 'other',
#      'url': 'https://covid.cdc.gov/covid-data-tracker/#vaccinations',
#      'name': 'Centers for Disease Control and Prevention'}],
#    'anomalies': []},
#   'vaccinationsInitiated': {'sources': [{'type': 'other',
#      'url': 'https://covid.cdc.gov/covid-data-tracker/#vaccinations',
#      'name': 'Centers for Disease Control and Prevention'}],
#    'anomalies': []},
#   'vaccinationsCompleted': {'sources': [{'type': 'other',
#      'url': 'https://covid.cdc.gov/covid-data-tracker/#vaccinations',
#      'name': 'Centers for Disease Control and Prevention'}],
#    'anomalies': []},
#   'testPositivityRatio': {'sources': [{'type': 'HHSTesting',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'caseDensity': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'contactTracerCapacityRatio': {'sources': [{'type': 'TestAndTrace',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'infectionRate': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'infectionRateCI90': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'icuHeadroomRatio': {'sources': [{'type': 'HHSHospital',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'icuCapacityRatio': {'sources': [{'type': 'HHSHospital',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'vaccinationsInitiatedRatio': None,
#   'vaccinationsCompletedRatio': None},
#  'lastUpdatedDate': '2021-03-11',
#  'url': 'https://covidactnow.org/us/washington-wa',
#  'metricsTimeseries': [{'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-14'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-15'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-16'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-17'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-18'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-19'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-20'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0018760229836078178,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-21'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0018760229836078178,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.5,
#    'infectionRateCI90': 1.1547005383800002,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-22'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0018760229836078178,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.5,
#    'infectionRateCI90': 1.1547005383800002,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-23'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0018760229836078178,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.5,
#    'infectionRateCI90': 1.1547005383800002,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-24'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0018760229836078178,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.5,
#    'infectionRateCI90': 1.1547005383800002,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-25'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0018760229836078178,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.5,
#    'infectionRateCI90': 1.1547005383800002,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-26'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0018760229836078178,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.5002243680200003,
#    'infectionRateCI90': 1.1546357689099997,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-27'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.5005076562200002,
#    'infectionRateCI90': 1.15455399065,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-28'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.50086662715,
#    'infectionRateCI90': 1.15445036467,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-29'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.50131826972,
#    'infectionRateCI90': 1.1543199866899996,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-30'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.5018785118,
#    'infectionRateCI90': 1.15415825874,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-01-31'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.50256051477,
#    'infectionRateCI90': 1.15396138143,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-01'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.5033727333899998,
#    'infectionRateCI90': 1.1537269141100002,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-02'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.50543833989,
#    'infectionRateCI90': 1.1531306248800002,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-03'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.50902183377,
#    'infectionRateCI90': 1.1520961592999999,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-04'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.5141532256499999,
#    'infectionRateCI90': 1.15061485406,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-05'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.5210164756,
#    'infectionRateCI90': 1.1486336044599998,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-06'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.52957357361,
#    'infectionRateCI90': 1.1461633830399998,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-07'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.5400218130899999,
#    'infectionRateCI90': 1.1431472361000006,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-08'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.55287854706,
#    'infectionRateCI90': 1.13943581669,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-09'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.56909626774,
#    'infectionRateCI90': 1.1347541639899998,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-10'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.58965345431,
#    'infectionRateCI90': 1.1288198153900004,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-11'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.61460122946,
#    'infectionRateCI90': 1.1216180130399998,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-12'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.64530011007,
#    'infectionRateCI90': 1.11275600955,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-13'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.67969495289,
#    'infectionRateCI90': 1.1028270736699997,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-14'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.7182732906599998,
#    'infectionRateCI90': 1.1840665098900003,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-15'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.76047115688,
#    'infectionRateCI90': 1.21229955402,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-16'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.8057957454900002,
#    'infectionRateCI90': 1.22808298576,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-17'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.8554224566799997,
#    'infectionRateCI90': 1.2253039936100005,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-18'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.90617459971,
#    'infectionRateCI90': 1.21642661459,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-19'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.9574781585299998,
#    'infectionRateCI90': 1.1900695474600007,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-20'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 2.00810679637,
#    'infectionRateCI90': 1.1696808159200005,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-21'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 2.0566994241,
#    'infectionRateCI90': 1.1383328245,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-22'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 2.10120529963,
#    'infectionRateCI90': 1.0792970633499999,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-23'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.007504091934431271,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 2.14085518083,
#    'infectionRateCI90': 1.0158896043400003,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-24'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.007504091934431271,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 2.17394952282,
#    'infectionRateCI90': 0.9601480691699997,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-25'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.007504091934431271,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 2.19921082493,
#    'infectionRateCI90': 0.8316122028499997,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-26'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.007504091934431271,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 2.21615356407,
#    'infectionRateCI90': 0.7458922176599998,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-27'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.011256137901646906,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 2.22306544585,
#    'infectionRateCI90': 0.6688413942700002,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-28'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.01688420685247036,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 2.2203884338,
#    'infectionRateCI90': 0.5945586460799994,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-02-29'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.030016367737725085,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 2.20852057471,
#    'infectionRateCI90': 0.5864375965199997,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-01'},
#   {'testPositivityRatio': 0.32727272727272727,
#    'caseDensity': 0.03376841370494072,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 2.18808649728,
#    'infectionRateCI90': 0.49996036350000006,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-02'},
#   {'testPositivityRatio': 0.2641509433962264,
#    'caseDensity': 0.050652620557411085,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 2.16065894125,
#    'infectionRateCI90': 0.4443694873199999,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-03'},
#   {'testPositivityRatio': 0.18248175182481752,
#    'caseDensity': 0.07879296531152835,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 2.12642519447,
#    'infectionRateCI90': 0.3907433891700003,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-04'},
#   {'testPositivityRatio': 0.16129032258064516,
#    'caseDensity': 0.13132160885254726,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 2.08762402096,
#    'infectionRateCI90': 0.33843579354,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-05'},
#   {'testPositivityRatio': 0.15192307692307694,
#    'caseDensity': 0.14820581570501762,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 2.0448824171099997,
#    'infectionRateCI90': 0.28149219949000015,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-06'},
#   {'testPositivityRatio': 0.13534822601839686,
#    'caseDensity': 0.1876022983607818,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.9993684592900003,
#    'infectionRateCI90': 0.2542164285399995,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-07'},
#   {'testPositivityRatio': 0.13149847094801223,
#    'caseDensity': 0.23262684996736943,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.95300703252,
#    'infectionRateCI90': 0.22141179812000011,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-08'},
#   {'testPositivityRatio': 0.13506916192026036,
#    'caseDensity': 0.29265958544281956,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.90608709613,
#    'infectionRateCI90': 0.19454189823,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-09'},
#   {'testPositivityRatio': 0.13260869565217392,
#    'caseDensity': 0.463377676951131,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.8617580213599998,
#    'infectionRateCI90': 0.1842445890900002,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-10'},
#   {'testPositivityRatio': 0.1213307240704501,
#    'caseDensity': 0.545922688229875,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.81969946977,
#    'infectionRateCI90': 0.16751833367000013,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-11'},
#   {'testPositivityRatio': 0.11116883116883118,
#    'caseDensity': 0.6453519063610894,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.78130750431,
#    'infectionRateCI90': 0.16128063138999993,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-12'},
#   {'testPositivityRatio': 0.09737991266375547,
#    'caseDensity': 0.7973097680333227,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.7458751504900003,
#    'infectionRateCI90': 0.1426415574399995,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-13'},
#   {'testPositivityRatio': 0.09976340694006308,
#    'caseDensity': 0.9361354688203012,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.71202269891,
#    'infectionRateCI90': 0.1350934103800001,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-14'},
#   {'testPositivityRatio': 0.08713984539704848,
#    'caseDensity': 1.0017962732465748,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.68173413086,
#    'infectionRateCI90': 0.13806346414999981,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-15'},
#   {'testPositivityRatio': 0.07180500658761528,
#    'caseDensity': 1.153754134918808,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.6537543007,
#    'infectionRateCI90': 0.11149952923000006,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-16'},
#   {'testPositivityRatio': 0.06094750320102432,
#    'caseDensity': 1.1800184566893175,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.6270759115399998,
#    'infectionRateCI90': 0.1307479222000003,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-17'},
#   {'testPositivityRatio': 0.05862143010521795,
#    'caseDensity': 1.2907038127221788,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.60129478167,
#    'infectionRateCI90': 0.13819029332999988,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-18'},
#   {'testPositivityRatio': 0.06214570648750787,
#    'caseDensity': 1.5177025937387247,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.5761213141100001,
#    'infectionRateCI90': 0.1396837447799999,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-19'},
#   {'testPositivityRatio': 0.07087854392719635,
#    'caseDensity': 1.6752885243617814,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.5501609473500002,
#    'infectionRateCI90': 0.13563085176,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-20'},
#   {'testPositivityRatio': 0.06809949287611687,
#    'caseDensity': 1.9623200408537773,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.52328874692,
#    'infectionRateCI90': 0.1202941770699999,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-21'},
#   {'testPositivityRatio': 0.07233806975456726,
#    'caseDensity': 2.1930708678375392,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.4949408415,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-22'},
#   {'testPositivityRatio': 0.07252573238321457,
#    'caseDensity': 2.451962039575418,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.46459040566,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-23'},
#   {'testPositivityRatio': 0.07558179923584576,
#    'caseDensity': 2.9284718774118037,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.43230137428,
#    'infectionRateCI90': 0.10614545027000011,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-24'},
#   {'testPositivityRatio': 0.07762743497025544,
#    'caseDensity': 2.9247198314445884,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.39772393393,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-25'},
#   {'testPositivityRatio': 0.07728360590347028,
#    'caseDensity': 3.714525507543479,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.36143608436,
#    'infectionRateCI90': 0.09999999999999987,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-26'},
#   {'testPositivityRatio': 0.07706911359218914,
#    'caseDensity': 4.438670379216097,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.32364209566,
#    'infectionRateCI90': 0.10000000000000031,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-27'},
#   {'testPositivityRatio': 0.07851786501985002,
#    'caseDensity': 4.9827170444623645,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.28421187355,
#    'infectionRateCI90': 0.09999999999999987,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-28'},
#   {'testPositivityRatio': 0.08048307872560947,
#    'caseDensity': 5.727498168954669,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.24424171746,
#    'infectionRateCI90': 0.09999999999999987,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-29'},
#   {'testPositivityRatio': 0.08395197507102924,
#    'caseDensity': 5.776274766528471,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.2029018106799998,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-30'},
#   {'testPositivityRatio': 0.08584858980702624,
#    'caseDensity': 5.2978889057084775,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.1608175459799999,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-31'},
#   {'testPositivityRatio': 0.09062036840990896,
#    'caseDensity': 5.635573042757885,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.11914444662,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-01'},
#   {'testPositivityRatio': 0.09742268041237113,
#    'caseDensity': 6.337205638627209,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.0784685974500001,
#    'infectionRateCI90': 0.09999999999999987,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-02'},
#   {'testPositivityRatio': 0.10152947028102462,
#    'caseDensity': 5.997645478594194,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.0394756845,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-03'},
#   {'testPositivityRatio': 0.10656885628542846,
#    'caseDensity': 5.980761271741724,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.00289137037,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-04'},
#   {'testPositivityRatio': 0.10590827709681863,
#    'caseDensity': 5.793158973380942,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.9688577858,
#    'infectionRateCI90': 0.09999999999999987,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-05'},
#   {'testPositivityRatio': 0.10538389848734676,
#    'caseDensity': 6.012653662463056,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.937314752669,
#    'infectionRateCI90': 0.10000000000099996,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-06'},
#   {'testPositivityRatio': 0.10610653962754439,
#    'caseDensity': 6.359717914430503,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.909410452385,
#    'infectionRateCI90': 0.09999999999499987,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-07'},
#   {'testPositivityRatio': 0.10493056065838784,
#    'caseDensity': 6.582964649479833,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.885520018592,
#    'infectionRateCI90': 0.09999999999999998,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-08'},
#   {'testPositivityRatio': 0.10144622297107554,
#    'caseDensity': 5.671217479446433,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.8661585177429999,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-09'},
#   {'testPositivityRatio': 0.09737215909090909,
#    'caseDensity': 5.4798631351184355,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.85146964271,
#    'infectionRateCI90': 0.09999999999999998,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-10'},
#   {'testPositivityRatio': 0.10314229999083876,
#    'caseDensity': 5.117790699282128,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.8416438968019999,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-11'},
#   {'testPositivityRatio': 0.10340861163298953,
#    'caseDensity': 4.5568598271833896,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.836771173337,
#    'infectionRateCI90': 0.09999999999999998,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-12'},
#   {'testPositivityRatio': 0.10351231838281742,
#    'caseDensity': 4.0559616905601015,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.836325237877,
#    'infectionRateCI90': 0.09999999999999998,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-13'},
#   {'testPositivityRatio': 0.10411698866124872,
#    'caseDensity': 3.8045746107566547,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.840018480931,
#    'infectionRateCI90': 0.09999999999999998,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-14'},
#   {'testPositivityRatio': 0.10402467895831839,
#    'caseDensity': 3.204247256002153,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.847969108887,
#    'infectionRateCI90': 0.09999999999999998,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-15'},
#   {'testPositivityRatio': 0.10417011613879887,
#    'caseDensity': 2.9472321072478818,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.859562045853,
#    'infectionRateCI90': 0.09999999999999998,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-16'},
#   {'testPositivityRatio': 0.10432723558361966,
#    'caseDensity': 2.9847525669200383,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.874415067447,
#    'infectionRateCI90': 0.09999999999999998,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-17'},
#   {'testPositivityRatio': 0.10304406073236082,
#    'caseDensity': 3.0447853023954883,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.891412159282,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-18'},
#   {'testPositivityRatio': 0.0996489638772506,
#    'caseDensity': 2.720233326231336,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.910099828591,
#    'infectionRateCI90': 0.099999999999,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-19'},
#   {'testPositivityRatio': 0.09783888487979035,
#    'caseDensity': 3.204247256002153,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.929504001804,
#    'infectionRateCI90': 0.09999999999600018,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-20'},
#   {'testPositivityRatio': 0.09354429375842653,
#    'caseDensity': 3.1873630491496825,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.9486632098100001,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-21'},
#   {'testPositivityRatio': 0.08767576509511994,
#    'caseDensity': 3.3768413704940725,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.967081337852,
#    'infectionRateCI90': 0.09999999999799991,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-22'},
#   {'testPositivityRatio': 0.08433962264150943,
#    'caseDensity': 3.3787173934776797,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.9841843483239999,
#    'infectionRateCI90': 0.09999999999600007,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-23'},
#   {'testPositivityRatio': 0.0854181972854878,
#    'caseDensity': 3.223007485838231,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.9996592735330001,
#    'infectionRateCI90': 0.10402140771699986,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-24'},
#   {'testPositivityRatio': 0.08115081924912915,
#    'caseDensity': 3.2173794168874075,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.013241413,
#    'infectionRateCI90': 0.10010058177000003,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-25'},
#   {'testPositivityRatio': 0.08333707915674024,
#    'caseDensity': 3.5269232091826974,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.02383221094,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-26'},
#   {'testPositivityRatio': 0.08210264971533753,
#    'caseDensity': 3.1948671410841136,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.03144885403,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-27'},
#   {'testPositivityRatio': 0.08038951184554421,
#    'caseDensity': 3.2924203362317206,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.0360404133399999,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-28'},
#   {'testPositivityRatio': 0.0809832737543581,
#    'caseDensity': 3.534427301117129,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.03735433961,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-29'},
#   {'testPositivityRatio': 0.08164999420648102,
#    'caseDensity': 3.4387501289531297,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.03580778919,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-30'},
#   {'testPositivityRatio': 0.07938573659552317,
#    'caseDensity': 3.633856519248343,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.03137010794,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-01'},
#   {'testPositivityRatio': 0.07834868494062812,
#    'caseDensity': 3.410609784199013,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.02492773334,
#    'infectionRateCI90': 0.09999999999999987,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-02'},
#   {'testPositivityRatio': 0.07780162223111338,
#    'caseDensity': 4.125374540953592,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.0163693385700001,
#    'infectionRateCI90': 0.09999999999999987,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-03'},
#   {'testPositivityRatio': 0.07753271028037383,
#    'caseDensity': 3.9190120127567316,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.00588810574,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-04'},
#   {'testPositivityRatio': 0.07626208378088078,
#    'caseDensity': 3.881491553084575,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.994197086724,
#    'infectionRateCI90': 0.09999999999600018,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-05'},
#   {'testPositivityRatio': 0.08077099586966499,
#    'caseDensity': 4.47056276993743,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.982094494786,
#    'infectionRateCI90': 0.100000000004,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-06'},
#   {'testPositivityRatio': 0.07844049141572686,
#    'caseDensity': 4.451802540101352,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.9699736411290001,
#    'infectionRateCI90': 0.10000000000099973,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-07'},
#   {'testPositivityRatio': 0.07628485826227241,
#    'caseDensity': 4.395521850593117,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.958640129506,
#    'infectionRateCI90': 0.10000000000400011,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-08'},
#   {'testPositivityRatio': 0.07389879868947943,
#    'caseDensity': 4.213547621183158,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.948495376268,
#    'infectionRateCI90': 0.10000000000200004,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-09'},
#   {'testPositivityRatio': 0.07277814112346487,
#    'caseDensity': 3.448130243871169,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.9395422461480001,
#    'infectionRateCI90': 0.10000000000199982,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-10'},
#   {'testPositivityRatio': 0.07125746362043692,
#    'caseDensity': 3.9865488401666127,
#    'contactTracerCapacityRatio': 0.46117647058823535,
#    'infectionRate': 0.9327256836769999,
#    'infectionRateCI90': 0.10000000000299991,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-11'},
#   {'testPositivityRatio': 0.06858932814862821,
#    'caseDensity': 4.029697368789592,
#    'contactTracerCapacityRatio': 0.45623836126629425,
#    'infectionRate': 0.927989377501,
#    'infectionRateCI90': 0.099999999999,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-12'},
#   {'testPositivityRatio': 0.06120469810710822,
#    'caseDensity': 3.037281210461057,
#    'contactTracerCapacityRatio': 0.6053119209388512,
#    'infectionRate': 0.926020749152,
#    'infectionRateCI90': 0.09999999999800002,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-13'},
#   {'testPositivityRatio': 0.059083300687346414,
#    'caseDensity': 3.140462474559487,
#    'contactTracerCapacityRatio': 1.146594982078853,
#    'infectionRate': 0.926740597436,
#    'infectionRateCI90': 0.10000000000400011,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-14'},
#   {'testPositivityRatio': 0.05749776340238112,
#    'caseDensity': 3.1029420148873306,
#    'contactTracerCapacityRatio': 1.1604594921402662,
#    'infectionRate': 0.930399325332,
#    'infectionRateCI90': 0.09999999999799991,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-15'},
#   {'testPositivityRatio': 0.05738253850763103,
#    'caseDensity': 3.202371233018545,
#    'contactTracerCapacityRatio': 1.1244288224956065,
#    'infectionRate': 0.93673499795,
#    'infectionRateCI90': 0.09999999999999998,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-16'},
#   {'testPositivityRatio': 0.05426302832772789,
#    'caseDensity': 3.2511478305923487,
#    'contactTracerCapacityRatio': 1.1075591459896132,
#    'infectionRate': 0.9454680069560001,
#    'infectionRateCI90': 0.10000000000400011,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-17'},
#   {'testPositivityRatio': 0.053598364227533266,
#    'caseDensity': 2.9716204060347833,
#    'contactTracerCapacityRatio': 1.2117424242424244,
#    'infectionRate': 0.956472842614,
#    'infectionRateCI90': 0.09999999999600007,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-18'},
#   {'testPositivityRatio': 0.05362868922190956,
#    'caseDensity': 3.012892911674155,
#    'contactTracerCapacityRatio': 1.195143212951432,
#    'infectionRate': 0.968929890573,
#    'infectionRateCI90': 0.09999999999700016,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-19'},
#   {'testPositivityRatio': 0.050189680061771914,
#    'caseDensity': 3.0354051874774495,
#    'contactTracerCapacityRatio': 1.1862793572311494,
#    'infectionRate': 0.982524182388,
#    'infectionRateCI90': 0.10000000000200004,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-20'},
#   {'testPositivityRatio': 0.04777503892060197,
#    'caseDensity': 2.662076613739494,
#    'contactTracerCapacityRatio': 2.0935870331219166,
#    'infectionRate': 0.996845319023,
#    'infectionRateCI90': 0.09999999999700004,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-21'},
#   {'testPositivityRatio': 0.04759889304899886,
#    'caseDensity': 2.6170520621329056,
#    'contactTracerCapacityRatio': 2.129605734767025,
#    'infectionRate': 1.01134767456,
#    'infectionRateCI90': 0.09999999999999987,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-22'},
#   {'testPositivityRatio': 0.05027932960893854,
#    'caseDensity': 2.6339362689853765,
#    'contactTracerCapacityRatio': 2.1159544159544157,
#    'infectionRate': 1.02537404617,
#    'infectionRateCI90': 0.10237169494999998,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-23'},
#   {'testPositivityRatio': 0.0545282588135538,
#    'caseDensity': 2.7671339008215314,
#    'contactTracerCapacityRatio': 2.014101694915254,
#    'infectionRate': 1.03842817575,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-24'},
#   {'testPositivityRatio': 0.05711487148309522,
#    'caseDensity': 2.830918682264197,
#    'contactTracerCapacityRatio': 1.9687210072895958,
#    'infectionRate': 1.05024882,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-25'},
#   {'testPositivityRatio': 0.05717881560597299,
#    'caseDensity': 2.9078356245921175,
#    'contactTracerCapacityRatio': 1.9166451612903226,
#    'infectionRate': 1.06052192261,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-26'},
#   {'testPositivityRatio': 0.0607708726705525,
#    'caseDensity': 3.2173794168874075,
#    'contactTracerCapacityRatio': 1.7322448979591836,
#    'infectionRate': 1.06862908456,
#    'infectionRateCI90': 0.10143204630000024,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-27'},
#   {'testPositivityRatio': 0.06227632126508531,
#    'caseDensity': 3.3974776233137582,
#    'contactTracerCapacityRatio': 1.6404196576477084,
#    'infectionRate': 1.07483480713,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-28'},
#   {'testPositivityRatio': 0.061464017296406874,
#    'caseDensity': 3.472518542658071,
#    'contactTracerCapacityRatio': 1.6049702863317123,
#    'infectionRate': 1.07925472748,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-29'},
#   {'testPositivityRatio': 0.06134993893038064,
#    'caseDensity': 3.523171163215482,
#    'contactTracerCapacityRatio': 1.5818956336528223,
#    'infectionRate': 1.08165675259,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-30'},
#   {'testPositivityRatio': 0.059515895671215735,
#    'caseDensity': 3.423741945084268,
#    'contactTracerCapacityRatio': 1.627835616438356,
#    'infectionRate': 1.08211491817,
#    'infectionRateCI90': 0.09999999999999987,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-31'},
#   {'testPositivityRatio': 0.05821616030037163,
#    'caseDensity': 3.7651781281008905,
#    'contactTracerCapacityRatio': 1.4802192326856003,
#    'infectionRate': 1.08148906775,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-01'},
#   {'testPositivityRatio': 0.05722503408475431,
#    'caseDensity': 3.883367576068183,
#    'contactTracerCapacityRatio': 0.45990338164251204,
#    'infectionRate': 1.07988500615,
#    'infectionRateCI90': 0.09999999999999987,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-02'},
#   {'testPositivityRatio': 0.05146978172644511,
#    'caseDensity': 3.660120841018853,
#    'contactTracerCapacityRatio': 0.4879548949256791,
#    'infectionRate': 1.0778299193799998,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-03'},
#   {'testPositivityRatio': 0.05120828538550058,
#    'caseDensity': 3.5794518527237162,
#    'contactTracerCapacityRatio': 0.49895178197065,
#    'infectionRate': 1.0759237599,
#    'infectionRateCI90': 0.09999999999999987,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-04'},
#   {'testPositivityRatio': 0.05319504851120776,
#    'caseDensity': 4.0690938514453565,
#    'contactTracerCapacityRatio': 0.4389119409866298,
#    'infectionRate': 1.07414039422,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-05'},
#   {'testPositivityRatio': 0.04999090602021461,
#    'caseDensity': 4.0315733917732,
#    'contactTracerCapacityRatio': 0.44299674267100975,
#    'infectionRate': 1.07298449394,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-06'},
#   {'testPositivityRatio': 0.0519015420798033,
#    'caseDensity': 4.221051713117591,
#    'contactTracerCapacityRatio': 0.42311111111111105,
#    'infectionRate': 1.07303560095,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-07'},
#   {'testPositivityRatio': 0.05178945137619539,
#    'caseDensity': 4.354249344953745,
#    'contactTracerCapacityRatio': 0.41016803102111166,
#    'infectionRate': 1.0743777703,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-08'},
#   {'testPositivityRatio': 0.04985224206604138,
#    'caseDensity': 4.104738288133905,
#    'contactTracerCapacityRatio': 0.43510054844606955,
#    'infectionRate': 1.07689317856,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-09'},
#   {'testPositivityRatio': 0.050863531995607475,
#    'caseDensity': 4.059713736527319,
#    'contactTracerCapacityRatio': 0.43992606284658037,
#    'infectionRate': 1.08088929684,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-10'},
#   {'testPositivityRatio': 0.05013112297461833,
#    'caseDensity': 4.076597943379788,
#    'contactTracerCapacityRatio': 0.4381040036815462,
#    'infectionRate': 1.0862245544700002,
#    'infectionRateCI90': 0.09999999999999987,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-11'},
#   {'testPositivityRatio': 0.046229700999683356,
#    'caseDensity': 3.8083266567238705,
#    'contactTracerCapacityRatio': 0.4689655172413793,
#    'infectionRate': 1.0926074788700002,
#    'infectionRateCI90': 0.09999999999999987,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-12'},
#   {'testPositivityRatio': 0.04404379163252012,
#    'caseDensity': 4.039077483707632,
#    'contactTracerCapacityRatio': 0.4421737111007897,
#    'infectionRate': 1.0997483023999999,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-13'},
#   {'testPositivityRatio': 0.03965385892602504,
#    'caseDensity': 3.8852435990517904,
#    'contactTracerCapacityRatio': 0.4596813133751811,
#    'infectionRate': 1.1075599784899999,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-14'},
#   {'testPositivityRatio': 0.03899124912306613,
#    'caseDensity': 3.722029599477911,
#    'contactTracerCapacityRatio': 0.47983870967741926,
#    'infectionRate': 1.115862452,
#    'infectionRateCI90': 0.10000000000000009,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-15'},
#   {'testPositivityRatio': 0.039761361642393404,
#    'caseDensity': 4.039077483707632,
#    'contactTracerCapacityRatio': 0.4421737111007897,
#    'infectionRate': 1.1238584687,
#    'infectionRateCI90': 0.10000000000000009,
# ...
#   {'overall': 0, 'date': '2020-02-07'},
#   {'overall': 0, 'date': '2020-02-08'},
#   {'overall': 0, 'date': '2020-02-09'},
#   {'overall': 0, 'date': '2020-02-10'},
#   {'overall': 0, 'date': '2020-02-11'},
#   {'overall': 0, 'date': '2020-02-12'},
#   {'overall': 0, 'date': '2020-02-13'},
#   {'overall': 0, 'date': '2020-02-14'},
#   {'overall': 0, 'date': '2020-02-15'},
#   {'overall': 0, 'date': '2020-02-16'},
#   {'overall': 0, 'date': '2020-02-17'},
#   {'overall': 0, 'date': '2020-02-18'},
#   {'overall': 0, 'date': '2020-02-19'},
#   {'overall': 0, 'date': '2020-02-20'},
#   {'overall': 0, 'date': '2020-02-21'},
#   {'overall': 0, 'date': '2020-02-22'},
#   {'overall': 0, 'date': '2020-02-23'},
#   {'overall': 0, 'date': '2020-02-24'},
#   {'overall': 0, 'date': '2020-02-25'},
#   {'overall': 0, 'date': '2020-02-26'},
#   {'overall': 2, 'date': '2021-01-22'},
#   {'overall': 2, 'date': '2021-01-23'},
#   {'overall': 2, 'date': '2021-01-24'},
#   {'overall': 2, 'date': '2021-01-25'},
#   {'overall': 2, 'date': '2021-01-26'},
#   {'overall': 2, 'date': '2021-01-27'},
#   {'overall': 2, 'date': '2021-01-28'},
#   {'overall': 2, 'date': '2021-01-29'},
#   {'overall': 2, 'date': '2021-01-30'},
#   {'overall': 2, 'date': '2021-01-31'},
#   {'overall': 2, 'date': '2021-02-01'},
#   {'overall': 2, 'date': '2021-02-02'},
#   {'overall': 2, 'date': '2021-02-03'},
#   {'overall': 2, 'date': '2021-02-04'},
#   {'overall': 2, 'date': '2021-02-05'},
#   {'overall': 2, 'date': '2021-02-06'},
#   {'overall': 2, 'date': '2021-02-07'},
#   {'overall': 2, 'date': '2021-02-08'},
#   {'overall': 2, 'date': '2021-02-09'},
#   {'overall': 2, 'date': '2021-02-10'},
#   {'overall': 2, 'date': '2021-02-11'},
#   {'overall': 2, 'date': '2021-02-12'},
#   {'overall': 2, 'date': '2021-02-13'},
#   {'overall': 2, 'date': '2021-02-14'},
#   {'overall': 1, 'date': '2021-02-15'},
#   {'overall': 2, 'date': '2021-02-16'},
#   {'overall': 2, 'date': '2021-02-17'},
#   {'overall': 2, 'date': '2021-02-18'},
#   {'overall': 2, 'date': '2021-02-19'},
#   {'overall': 2, 'date': '2021-02-20'},
#   {'overall': 2, 'date': '2021-02-21'},
#   {'overall': 2, 'date': '2021-02-22'},
#   {'overall': 2, 'date': '2021-02-23'},
#   {'overall': 2, 'date': '2021-02-24'},
#   {'overall': 2, 'date': '2021-02-25'},
#   {'overall': 2, 'date': '2021-02-26'},
#   {'overall': 2, 'date': '2021-02-27'},
#   {'overall': 2, 'date': '2021-02-28'},
#   {'overall': 2, 'date': '2021-03-01'},
#   {'overall': 2, 'date': '2021-03-02'},
#   {'overall': 1, 'date': '2021-03-03'},
#   {'overall': 1, 'date': '2021-03-04'},
#   {'overall': 1, 'date': '2021-03-05'},
#   {'overall': 1, 'date': '2021-03-06'},
#   {'overall': 1, 'date': '2021-03-07'},
#   {'overall': 1, 'date': '2021-03-08'},
#   {'overall': 1, 'date': '2021-03-09'},
#   {'overall': 1, 'date': '2021-03-10'},
#   {'overall': 1, 'date': '2021-03-11'}]}

# %%
#Pull dictionary out of total data set in order to parse through in a for loop
response = response.get('actualsTimeseries')

# %%
#Create lists to hold the data you want
case_count = []
date = []
death = []
total_death = []
total_cases = []

# %%
# use for loop to pull out the data
for actualsTimeseries in range(0, len(response)):
    case_count.append(response[actualsTimeseries]['newCases'])
    date.append(response[actualsTimeseries]['date'])
    death.append(response[actualsTimeseries]['newDeaths'])
    total_death.append(response[actualsTimeseries]['deaths'])
    total_cases.append(response[actualsTimeseries]['cases'])

# %%
#create data frame to hold pulled data

WA_dict = {
    'Date': date,
    'Case Count': case_count,   
    'Death Count': death,
}

WA_data = pd.DataFrame.from_dict(WA_dict)

WA_data.dropna()
# Out:
#            Date  Case Count  Death Count
# 7    2020-01-21         1.0          0.0
# 8    2020-01-22         0.0          0.0
# 9    2020-01-23         0.0          0.0
# 10   2020-01-24         0.0          0.0
# 11   2020-01-25         0.0          0.0
# ..          ...         ...          ...
# 417  2021-03-06       568.0          3.0
# 418  2021-03-07        90.0          1.0
# 419  2021-03-08      1094.0         21.0
# 420  2021-03-09       711.0         12.0
# 421  2021-03-10       685.0         18.0
#
# [409 rows x 3 columns]

# %%
#reset the index
WA_data.reset_index()
# Out:
#      index        Date  Case Count  Death Count
# 0        0  2020-01-14         NaN          NaN
# 1        1  2020-01-15         NaN          NaN
# 2        2  2020-01-16         NaN          NaN
# 3        3  2020-01-17         NaN          NaN
# 4        4  2020-01-18         NaN          NaN
# ..     ...         ...         ...          ...
# 418    418  2021-03-07        90.0          1.0
# 419    419  2021-03-08      1094.0         21.0
# 420    420  2021-03-09       711.0         12.0
# 421    421  2021-03-10       685.0         18.0
# 422    422  2021-03-11         NaN          NaN
#
# [423 rows x 4 columns]

# %%
#scale down the data and get rid of rows with 'NaN' to make the plot read better

clean_df = WA_data[WA_data.index % 10 == 0]  # Selects every 3rd row starting from 0

clean_df = clean_df.dropna()

# %%
clean_df
# Out:
#            Date  Case Count  Death Count
# 10   2020-01-24         0.0          0.0
# 20   2020-02-03         0.0          0.0
# 30   2020-02-13         0.0          0.0
# 40   2020-02-23         0.0          0.0
# 50   2020-03-04        15.0          1.0
# 60   2020-03-14        98.0          3.0
# 70   2020-03-24       368.0         13.0
# 80   2020-04-03       381.0         21.0
# 90   2020-04-13       133.0         14.0
# 100  2020-04-23       375.0         21.0
# 110  2020-05-03       560.0          7.0
# 120  2020-05-13       110.0          5.0
# 130  2020-05-23       214.0          1.0
# 140  2020-06-02       336.0          6.0
# 150  2020-06-12       404.0          9.0
# 160  2020-06-22       646.0          6.0
# 170  2020-07-02       663.0          3.0
# 180  2020-07-12       855.0         12.0
# 190  2020-07-22       696.0          3.0
# 200  2020-08-01       923.0         22.0
# 210  2020-08-11       394.0          5.0
# 220  2020-08-21       503.0         13.0
# 230  2020-08-31       596.0         10.0
# 240  2020-09-10       597.0          7.0
# 250  2020-09-20       283.0          0.0
# 260  2020-09-30       549.0          4.0
# 270  2020-10-10       386.0          1.0
# 280  2020-10-20       522.0         23.0
# 290  2020-10-30      1145.0          5.0
# 300  2020-11-09      2250.0         25.0
# 310  2020-11-19      2457.0         13.0
# 320  2020-11-29      1597.0          0.0
# 330  2020-12-09      3185.0         44.0
# 340  2020-12-19      1957.0          1.0
# 360  2021-01-08      4109.0         49.0
# 370  2021-01-18       443.0          3.0
# 380  2021-01-28      2438.0         34.0
# 390  2021-02-07       199.0          4.0
# 400  2021-02-17      1099.0         47.0
# 410  2021-02-27       633.0          0.0
# 420  2021-03-09       711.0         12.0

# %%
#Create line plot to showcase the data
plt.figure(figsize=(12, 9))
case_count = plt.plot(clean_df['Date'], clean_df.loc[:, 'Case Count'], color="blue", label="Case Count")

plt.xticks(rotation=90);

plt.title("Washington State COVID Count")
plt.xlabel("Date")
plt.ylabel("Case Numbers")

#make it look better?
plt.xlim(-0.75, len(clean_df['Date']))
#plt.ylim(, max(clean_df["Case Count"])+10)

#Export to image
plt.savefig("WA_Case_Count.png")
